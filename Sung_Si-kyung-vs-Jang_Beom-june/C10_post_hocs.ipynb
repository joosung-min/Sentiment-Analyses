# %%
import numpy as np
import pandas as pd
import os
import re

os.chdir("/content/drive/MyDrive/personal/Sentiment-Analyses/Sung_Si-kyung-vs-Jang_Beom-june/")
from A11_init_ import * # contains CLOVA id, secret key, url

# %%
comments_raw = pd.read_csv("./outputs/A10_comments_raw.csv")
counts = comments_raw.value_counts(subset = "ID").rename_axis('ID').reset_index(name='counts').head(10)
display(counts)
sum(counts["counts"])
# Out:
#          ID  counts
# 0    전승우승가능     122
# 1  곧발롱위너비닐신      82
# 2    클라우드22      76
# 3    김해코스트코      71
# 4     Fkdkd      64
# 5      내장지방      61
# 6     XTC-4      52
# 7    노하라히로시      45
# 8       자시안      44
# 9    bslbsl      43
# 660

# %%
comments_extract = pd.read_csv("./outputs/A11_comments_extract.csv")
counts2 = comments_extract.value_counts(subset = "ID").rename_axis('ID').reset_index(name='counts').head(10)
display(counts2)
sum(counts2["counts"])
# Out:
#          ID  counts
# 0    전승우승가능      66
# 1    클라우드22      45
# 2    김해코스트코      39
# 3     Fkdkd      33
# 4     XTC-4      31
# 5       맹모띠      30
# 6  곧발롱위너비닐신      26
# 7    서머스비러버      25
# 8  courteou      24
# 9      내장지방      23
# 342
